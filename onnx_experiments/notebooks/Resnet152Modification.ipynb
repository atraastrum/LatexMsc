# %%
import onnx
from onnx import optimizer
import mxnet as mx
import mxnet.contrib.onnx as onnx_mxnet
from mxnet.gluon.data.vision import transforms

import numpy as np

# %%
# Pixel values of img must be already scalled to be in range [0,1]
def resize_crop_normalize_bachify(img):   
    transform_fn = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
    img = transform_fn(img)
    # Add one more axis to tensor 3x224x224 -> 1x3x224x224
    # This operation is called bachification
    img = img.expand_dims(axis=0)
    return img

def resize_crop_bachify(img):   
    transform_fn = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor()
    ])
    img = transform_fn(img)
    # Add one more axis to tensor 3x224x224 -> 1x3x224x224
    # This operation is called bachification
    img = img.expand_dims(axis=0)
    return img

def inference(model, argp, auxp):
    ex = model.bind(
        ctx=mx.cpu(),
        args = argp,
        aux_states= auxp
    )    
    ex.forward()
    return ex.outputs[0]

# %%
try:
    img = mx.image.imread('kitten.jpg')
except:
    mx.test_utils.download('https://s3.amazonaws.com/model-server/inputs/kitten.jpg')
    img = mx.image.imread('kitten.jpg')
# Shape of img is WxHx3

# %%
def get_labels():
    with open('synset.txt', 'r') as f:
        labels = [l.rstrip() for l in f]    
    return labels    
try:
    labels= get_labels()
except:
    mx.test_utils.download('https://s3.amazonaws.com/onnx-model-zoo/synset.txt')
    labels= get_labels()

# %%
# Can take a long time
try:
    original_model, arg_params, aux_params  = onnx_mxnet.import_model('resnet152v2.onnx')
except:
    mx.test_utils.download('https://s3.amazonaws.com/onnx-model-zoo/resnet/resnet152v2/resnet152v2.onnx')
    original_model, arg_params, aux_params  = onnx_mxnet.import_model('resnet152v2.onnx')

# %% [markdown]
# ## Inference with original model

# %%
input_tensor = resize_crop_normalize_bachify(img)

arguments = arg_params.copy()
arguments.update(
    {
        'data' : input_tensor
    }
)

output_tensor = inference(original_model, arguments, aux_params)

# %%
scores = mx.nd.softmax(output_tensor).asnumpy()
scores = np.squeeze(scores)
a = np.argsort(scores)[::-1]
for i in a[0:5]:
    print('class=%s ; probability=%f' %(labels[i],scores[i]))
# Out:
# class=n02123045 tabby, tabby cat ; probability=0.724649
# class=n02123159 tiger cat ; probability=0.267098
# class=n02124075 Egyptian cat ; probability=0.007431
# class=n02127052 lynx, catamount ; probability=0.000183
# class=n02123394 Persian cat ; probability=0.000131

# %% [markdown]
# ## Inference with preprocessing added

# %%
# Create computational graph that standardizes the data
preprocess_net = mx.sym.Variable('input')
translation = mx.sym.Variable('preprocessing_translation', shape = (1,3,1,1), dtype=np.float32)
std = mx.sym.Variable('preprocessing_std', shape = (1,3,1,1), dtype=np.float32)

# Pixel values must also be translate and scalled by [0.485, 0.456, 0.406] and std = [0.229, 0.224, 0.225]
preprocess_net = mx.sym.broadcast_sub(preprocess_net, translation)
preprocess_net = mx.sym.broadcast_div(preprocess_net, std)

preprocess_params = {
    'preprocessing_translation': mx.nd.array([0.485, 0.456, 0.406]).reshape((1,3,1,1)),
    'preprocessing_std': mx.nd.array([0.229, 0.224, 0.225]).reshape((1,3,1,1))              
}

# %%
model_with_preprocessing = original_model(data=preprocess_net)

# %%
input_tensor = resize_crop_bachify(img)

arguments = arg_params.copy()
arguments.update(
    {
        'input' : input_tensor 
    }
)
arguments.update(preprocess_params)

# %%
output_tensor = inference(model_with_preprocessing, arguments, aux_params)

# %%
scores = mx.nd.softmax(output_tensor).asnumpy()
scores = np.squeeze(scores)
a = np.argsort(scores)[::-1]
for i in a[0:5]:
    print('class=%s ; probability=%f' %(labels[i],scores[i]))
# Out:
# class=n02123045 tabby, tabby cat ; probability=0.724649
# class=n02123159 tiger cat ; probability=0.267098
# class=n02124075 Egyptian cat ; probability=0.007431
# class=n02127052 lynx, catamount ; probability=0.000183
# class=n02123394 Persian cat ; probability=0.000131

# %% [markdown]
# ## Inference with postprocessing and preprocessing steps

# %%
full_model = mx.sym.softmax(data=model_with_preprocessing)
full_model = mx.sym.reshape(data=full_model, shape=(1000,))

# %%
output_tensor = inference(full_model, arguments, aux_params)
print(output_tensor.shape)
# Out:
# (1000,)

# %%
a = np.argsort(scores)[::-1]
for i in a[0:5]:
    print('class=%s ; probability=%f' %(labels[i],scores[i]))
# Out:
# class=n02123045 tabby, tabby cat ; probability=0.724649
# class=n02123159 tiger cat ; probability=0.267098
# class=n02124075 Egyptian cat ; probability=0.007431
# class=n02127052 lynx, catamount ; probability=0.000183
# class=n02123394 Persian cat ; probability=0.000131

# %% [markdown]
#  Looks like model produces correct results. We export it to ONNX format

# %%
parameters = arg_params.copy()
parameters.update(aux_params)
parameters.update(preprocess_params)
onnx_mxnet.export_model(
    sym=full_model, 
    params = parameters, 
    input_shape=[(1, 3, 224, 224)],
    onnx_file_path = 'full_model.onnx'
)
# Out:
# 'full_model.onnx'

# %% [markdown]
# ## Adding denotation to the model

# %% [markdown]
# Denotationg inputs and outputs of full model. Input has type image. Output has categorical output type.

# %%
# This can take a long time 
print('Loading model...')
model_proto = onnx.load('full_model.onnx')
print("Model loaded")
# Out:
# Loading model...
# Model loaded

# %%
graph_proto = model_proto.graph

# %% [markdown]
# ### Type Denotation

# %%
graph_proto.input[0].type.denotation = 'IMAGE'

# %%
graph_proto.output[0].type.denotation = 'CATEGORICAL_PROBABILITIES'

# %%
# Dimension Denotation

# %%
graph_proto.input[0].type.tensor_type.shape.dim[0].denotation = "DATA_BATCH"
graph_proto.input[0].type.tensor_type.shape.dim[1].denotation = "DATA_CHANNEL"
graph_proto.input[0].type.tensor_type.shape.dim[2].denotation = "DATA_FEATURE"
graph_proto.input[0].type.tensor_type.shape.dim[3].denotation = "DATA_FEATURE"

graph_proto.output[0].type.tensor_type.shape.dim[0].denotation = "DATA_PROBABILITY"

# %%
print(graph_proto.input[0])
# Out:
# name: "input"
# type {
#   tensor_type {
#     elem_type: FLOAT
#     shape {
#       dim {
#         dim_value: 1
#         denotation: "DATA_BATCH"
#       }
#       dim {
#         dim_value: 3
#         denotation: "DATA_CHANNEL"
#       }
#       dim {
#         dim_value: 224
#         denotation: "DATA_FEATURE"
#       }
#       dim {
#         dim_value: 224
#         denotation: "DATA_FEATURE"
#       }
#     }
#   }
#   denotation: "IMAGE"
# }

# %%
print(graph_proto.output[0])
# Out:
# name: "reshape0"
# type {
#   tensor_type {
#     elem_type: FLOAT
#     shape {
#       dim {
#         dim_value: 1000
#         denotation: "DATA_PROBABILITY"
#       }
#     }
#   }
#   denotation: "CATEGORICAL_PROBABILITIES"
# }

# %% [markdown]
# ### Model Metadata

# %%
meta_data_proto = model_proto.metadata_props

# %% [markdown]
# Metadata for input.

# %%
pixFormat = meta_data_proto.add()
pixFormat.key = "Image.BitmapPixelFormat"
pixFormat.value = "Rgb8"
colorSpace = meta_data_proto.add()
colorSpace.key = "Image.ColorSpaceGamma"
colorSpace.value = "SRGB"
nominalRange = meta_data_proto.add()
nominalRange.key = "Image.NominalPixelRange"
nominalRange.value = "Normalized_0_1"

# %%
print(model_proto.metadata_props)
# Out:
# [key: "Image.BitmapPixelFormat"
# value: "Rgb8"
# , key: "Image.ColorSpaceGamma"
# value: "SRGB"
# , key: "Image.NominalPixelRange"
# value: "Normalized_0_1"
# ]

# %% [markdown]
# Metadata for output.

# %%
for i, label in enumerate(labels):
    category_part = label[10:]
    category = meta_data_proto.add()
    category.key = 'Category_' + str(i)
    category.value = category_part

# %%
print(meta_data_proto)
# Out:
# [key: "Image.BitmapPixelFormat"
# value: "Rgb8"
# , key: "Image.ColorSpaceGamma"
# value: "SRGB"
# , key: "Image.NominalPixelRange"
# value: "Normalized_0_1"
# , key: "Category_0"
# value: "tench, Tinca tinca"
# , key: "Category_1"
# value: "goldfish, Carassius auratus"
# , key: "Category_2"
# value: "great white shark, white shark, man-eater, man-eating shark, Carcharodon carcharias"
# , key: "Category_3"
# value: "tiger shark, Galeocerdo cuvieri"
# , key: "Category_4"
# value: "hammerhead, hammerhead shark"
# , key: "Category_5"
# value: "electric ray, crampfish, numbfish, torpedo"
# , key: "Category_6"
# value: "stingray"
# , key: "Category_7"
# value: "cock"
# , key: "Category_8"
# value: "hen"
# , key: "Category_9"
# value: "ostrich, Struthio camelus"
# , key: "Category_10"
# value: "brambling, Fringilla montifringilla"
# , key: "Category_11"
# value: "goldfinch, Carduelis carduelis"
# , key: "Category_12"
# value: "house finch, linnet, Carpodacus mexicanus"
# , key: "Category_13"
# value: "junco, snowbird"
# , key: "Category_14"
# value: "indigo bunting, indigo finch, indigo bird, Passerina cyanea"
# , key: "Category_15"
# value: "robin, American robin, Turdus migratorius"
# , key: "Category_16"
# value: "bulbul"
# , key: "Category_17"
# value: "jay"
# , key: "Category_18"
# value: "magpie"
# , key: "Category_19"
# value: "chickadee"
# , key: "Category_20"
# value: "water ouzel, dipper"
# , key: "Category_21"
# value: "kite"
# , key: "Category_22"
# value: "bald eagle, American eagle, Haliaeetus leucocephalus"
# , key: "Category_23"
# value: "vulture"
# , key: "Category_24"
# value: "great grey owl, great gray owl, Strix nebulosa"
# , key: "Category_25"
# value: "European fire salamander, Salamandra salamandra"
# , key: "Category_26"
# value: "common newt, Triturus vulgaris"
# , key: "Category_27"
# value: "eft"
# , key: "Category_28"
# value: "spotted salamander, Ambystoma maculatum"
# , key: "Category_29"
# value: "axolotl, mud puppy, Ambystoma mexicanum"
# , key: "Category_30"
# value: "bullfrog, Rana catesbeiana"
# , key: "Category_31"
# value: "tree frog, tree-frog"
# , key: "Category_32"
# value: "tailed frog, bell toad, ribbed toad, tailed toad, Ascaphus trui"
# , key: "Category_33"
# value: "loggerhead, loggerhead turtle, Caretta caretta"
# , key: "Category_34"
# value: "leatherback turtle, leatherback, leathery turtle, Dermochelys coriacea"
# , key: "Category_35"
# value: "mud turtle"
# , key: "Category_36"
# value: "terrapin"
# , key: "Category_37"
# value: "box turtle, box tortoise"
# , key: "Category_38"
# value: "banded gecko"
# , key: "Category_39"
# value: "common iguana, iguana, Iguana iguana"
# , key: "Category_40"
# value: "American chameleon, anole, Anolis carolinensis"
# , key: "Category_41"
# value: "whiptail, whiptail lizard"
# , key: "Category_42"
# value: "agama"
# , key: "Category_43"
# value: "frilled lizard, Chlamydosaurus kingi"
# , key: "Category_44"
# value: "alligator lizard"
# , key: "Category_45"
# value: "Gila monster, Heloderma suspectum"
# , key: "Category_46"
# value: "green lizard, Lacerta viridis"
# , key: "Category_47"
# value: "African chameleon, Chamaeleo chamaeleon"
# , key: "Category_48"
# value: "Komodo dragon, Komodo lizard, dragon lizard, giant lizard, Varanus komodoensis"
# , key: "Category_49"
# value: "African crocodile, Nile crocodile, Crocodylus niloticus"
# , key: "Category_50"
# value: "American alligator, Alligator mississipiensis"
# , key: "Category_51"
# value: "triceratops"
# , key: "Category_52"
# value: "thunder snake, worm snake, Carphophis amoenus"
# , key: "Category_53"
# value: "ringneck snake, ring-necked snake, ring snake"
# , key: "Category_54"
# value: "hognose snake, puff adder, sand viper"
# , key: "Category_55"
# value: "green snake, grass snake"
# , key: "Category_56"
# value: "king snake, kingsnake"
# , key: "Category_57"
# value: "garter snake, grass snake"
# , key: "Category_58"
# value: "water snake"
# , key: "Category_59"
# value: "vine snake"
# , key: "Category_60"
# value: "night snake, Hypsiglena torquata"
# , key: "Category_61"
# value: "boa constrictor, Constrictor constrictor"
# , key: "Category_62"
# value: "rock python, rock snake, Python sebae"
# , key: "Category_63"
# value: "Indian cobra, Naja naja"
# , key: "Category_64"
# value: "green mamba"
# , key: "Category_65"
# value: "sea snake"
# , key: "Category_66"
# value: "horned viper, cerastes, sand viper, horned asp, Cerastes cornutus"
# , key: "Category_67"
# value: "diamondback, diamondback rattlesnake, Crotalus adamanteus"
# , key: "Category_68"
# value: "sidewinder, horned rattlesnake, Crotalus cerastes"
# , key: "Category_69"
# value: "trilobite"
# , key: "Category_70"
# value: "harvestman, daddy longlegs, Phalangium opilio"
# , key: "Category_71"
# value: "scorpion"
# , key: "Category_72"
# value: "black and gold garden spider, Argiope aurantia"
# , key: "Category_73"
# value: "barn spider, Araneus cavaticus"
# , key: "Category_74"
# value: "garden spider, Aranea diademata"
# , key: "Category_75"
# value: "black widow, Latrodectus mactans"
# , key: "Category_76"
# value: "tarantula"
# , key: "Category_77"
# value: "wolf spider, hunting spider"
# , key: "Category_78"
# value: "tick"
# , key: "Category_79"
# value: "centipede"
# , key: "Category_80"
# value: "black grouse"
# , key: "Category_81"
# value: "ptarmigan"
# , key: "Category_82"
# value: "ruffed grouse, partridge, Bonasa umbellus"
# , key: "Category_83"
# value: "prairie chicken, prairie grouse, prairie fowl"
# , key: "Category_84"
# value: "peacock"
# , key: "Category_85"
# value: "quail"
# , key: "Category_86"
# value: "partridge"
# , key: "Category_87"
# value: "African grey, African gray, Psittacus erithacus"
# , key: "Category_88"
# value: "macaw"
# , key: "Category_89"
# value: "sulphur-crested cockatoo, Kakatoe galerita, Cacatua galerita"
# , key: "Category_90"
# value: "lorikeet"
# , key: "Category_91"
# value: "coucal"
# , key: "Category_92"
# value: "bee eater"
# , key: "Category_93"
# value: "hornbill"
# , key: "Category_94"
# value: "hummingbird"
# , key: "Category_95"
# value: "jacamar"
# , key: "Category_96"
# value: "toucan"
# , key: "Category_97"
# value: "drake"
# , key: "Category_98"
# value: "red-breasted merganser, Mergus serrator"
# , key: "Category_99"
# value: "goose"
# , key: "Category_100"
# value: "black swan, Cygnus atratus"
# , key: "Category_101"
# value: "tusker"
# , key: "Category_102"
# value: "echidna, spiny anteater, anteater"
# , key: "Category_103"
# value: "platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus"
# , key: "Category_104"
# value: "wallaby, brush kangaroo"
# , key: "Category_105"
# value: "koala, koala bear, kangaroo bear, native bear, Phascolarctos cinereus"
# , key: "Category_106"
# value: "wombat"
# , key: "Category_107"
# value: "jellyfish"
# , key: "Category_108"
# value: "sea anemone, anemone"
# , key: "Category_109"
# value: "brain coral"
# , key: "Category_110"
# value: "flatworm, platyhelminth"
# , key: "Category_111"
# value: "nematode, nematode worm, roundworm"
# , key: "Category_112"
# value: "conch"
# , key: "Category_113"
# value: "snail"
# , key: "Category_114"
# value: "slug"
# , key: "Category_115"
# value: "sea slug, nudibranch"
# , key: "Category_116"
# value: "chiton, coat-of-mail shell, sea cradle, polyplacophore"
# , key: "Category_117"
# value: "chambered nautilus, pearly nautilus, nautilus"
# , key: "Category_118"
# value: "Dungeness crab, Cancer magister"
# , key: "Category_119"
# value: "rock crab, Cancer irroratus"
# , key: "Category_120"
# value: "fiddler crab"
# , key: "Category_121"
# value: "king crab, Alaska crab, Alaskan king crab, Alaska king crab, Paralithodes camtschatica"
# , key: "Category_122"
# value: "American lobster, Northern lobster, Maine lobster, Homarus americanus"
# , key: "Category_123"
# value: "spiny lobster, langouste, rock lobster, crawfish, crayfish, sea crawfish"
# , key: "Category_124"
# value: "crayfish, crawfish, crawdad, crawdaddy"
# , key: "Category_125"
# value: "hermit crab"
# , key: "Category_126"
# value: "isopod"
# , key: "Category_127"
# value: "white stork, Ciconia ciconia"
# , key: "Category_128"
# value: "black stork, Ciconia nigra"
# , key: "Category_129"
# value: "spoonbill"
# , key: "Category_130"
# value: "flamingo"
# , key: "Category_131"
# value: "little blue heron, Egretta caerulea"
# , key: "Category_132"
# value: "American egret, great white heron, Egretta albus"
# , key: "Category_133"
# value: "bittern"
# , key: "Category_134"
# value: "crane"
# , key: "Category_135"
# value: "limpkin, Aramus pictus"
# , key: "Category_136"
# value: "European gallinule, Porphyrio porphyrio"
# , key: "Category_137"
# value: "American coot, marsh hen, mud hen, water hen, Fulica americana"
# , key: "Category_138"
# value: "bustard"
# , key: "Category_139"
# value: "ruddy turnstone, Arenaria interpres"
# , key: "Category_140"
# value: "red-backed sandpiper, dunlin, Erolia alpina"
# , key: "Category_141"
# value: "redshank, Tringa totanus"
# , key: "Category_142"
# value: "dowitcher"
# , key: "Category_143"
# value: "oystercatcher, oyster catcher"
# , key: "Category_144"
# value: "pelican"
# , key: "Category_145"
# value: "king penguin, Aptenodytes patagonica"
# , key: "Category_146"
# value: "albatross, mollymawk"
# , key: "Category_147"
# value: "grey whale, gray whale, devilfish, Eschrichtius gibbosus, Eschrichtius robustus"
# , key: "Category_148"
# value: "killer whale, killer, orca, grampus, sea wolf, Orcinus orca"
# , key: "Category_149"
# value: "dugong, Dugong dugon"
# , key: "Category_150"
# value: "sea lion"
# , key: "Category_151"
# value: "Chihuahua"
# , key: "Category_152"
# value: "Japanese spaniel"
# , key: "Category_153"
# value: "Maltese dog, Maltese terrier, Maltese"
# , key: "Category_154"
# value: "Pekinese, Pekingese, Peke"
# , key: "Category_155"
# value: "Shih-Tzu"
# , key: "Category_156"
# value: "Blenheim spaniel"
# , key: "Category_157"
# value: "papillon"
# , key: "Category_158"
# value: "toy terrier"
# , key: "Category_159"
# value: "Rhodesian ridgeback"
# , key: "Category_160"
# value: "Afghan hound, Afghan"
# , key: "Category_161"
# value: "basset, basset hound"
# , key: "Category_162"
# value: "beagle"
# , key: "Category_163"
# value: "bloodhound, sleuthhound"
# , key: "Category_164"
# value: "bluetick"
# , key: "Category_165"
# value: "black-and-tan coonhound"
# , key: "Category_166"
# value: "Walker hound, Walker foxhound"
# , key: "Category_167"
# value: "English foxhound"
# , key: "Category_168"
# value: "redbone"
# , key: "Category_169"
# value: "borzoi, Russian wolfhound"
# , key: "Category_170"
# value: "Irish wolfhound"
# , key: "Category_171"
# value: "Italian greyhound"
# , key: "Category_172"
# value: "whippet"
# , key: "Category_173"
# value: "Ibizan hound, Ibizan Podenco"
# , key: "Category_174"
# value: "Norwegian elkhound, elkhound"
# , key: "Category_175"
# value: "otterhound, otter hound"
# , key: "Category_176"
# value: "Saluki, gazelle hound"
# , key: "Category_177"
# value: "Scottish deerhound, deerhound"
# , key: "Category_178"
# value: "Weimaraner"
# , key: "Category_179"
# value: "Staffordshire bullterrier, Staffordshire bull terrier"
# , key: "Category_180"
# value: "American Staffordshire terrier, Staffordshire terrier, American pit bull terrier, pit bull terrier"
# , key: "Category_181"
# value: "Bedlington terrier"
# , key: "Category_182"
# value: "Border terrier"
# , key: "Category_183"
# value: "Kerry blue terrier"
# , key: "Category_184"
# value: "Irish terrier"
# , key: "Category_185"
# value: "Norfolk terrier"
# , key: "Category_186"
# value: "Norwich terrier"
# , key: "Category_187"
# value: "Yorkshire terrier"
# , key: "Category_188"
# value: "wire-haired fox terrier"
# , key: "Category_189"
# value: "Lakeland terrier"
# , key: "Category_190"
# value: "Sealyham terrier, Sealyham"
# , key: "Category_191"
# value: "Airedale, Airedale terrier"
# , key: "Category_192"
# value: "cairn, cairn terrier"
# , key: "Category_193"
# value: "Australian terrier"
# , key: "Category_194"
# value: "Dandie Dinmont, Dandie Dinmont terrier"
# , key: "Category_195"
# value: "Boston bull, Boston terrier"
# , key: "Category_196"
# value: "miniature schnauzer"
# , key: "Category_197"
# value: "giant schnauzer"
# , key: "Category_198"
# value: "standard schnauzer"
# , key: "Category_199"
# value: "Scotch terrier, Scottish terrier, Scottie"
# , key: "Category_200"
# value: "Tibetan terrier, chrysanthemum dog"
# , key: "Category_201"
# value: "silky terrier, Sydney silky"
# , key: "Category_202"
# value: "soft-coated wheaten terrier"
# , key: "Category_203"
# value: "West Highland white terrier"
# , key: "Category_204"
# value: "Lhasa, Lhasa apso"
# , key: "Category_205"
# value: "flat-coated retriever"
# , key: "Category_206"
# value: "curly-coated retriever"
# , key: "Category_207"
# value: "golden retriever"
# , key: "Category_208"
# value: "Labrador retriever"
# , key: "Category_209"
# value: "Chesapeake Bay retriever"
# , key: "Category_210"
# value: "German short-haired pointer"
# , key: "Category_211"
# value: "vizsla, Hungarian pointer"
# , key: "Category_212"
# value: "English setter"
# , key: "Category_213"
# value: "Irish setter, red setter"
# , key: "Category_214"
# value: "Gordon setter"
# , key: "Category_215"
# value: "Brittany spaniel"
# , key: "Category_216"
# value: "clumber, clumber spaniel"
# , key: "Category_217"
# value: "English springer, English springer spaniel"
# , key: "Category_218"
# value: "Welsh springer spaniel"
# , key: "Category_219"
# value: "cocker spaniel, English cocker spaniel, cocker"
# , key: "Category_220"
# value: "Sussex spaniel"
# , key: "Category_221"
# value: "Irish water spaniel"
# , key: "Category_222"
# value: "kuvasz"
# , key: "Category_223"
# value: "schipperke"
# , key: "Category_224"
# value: "groenendael"
# , key: "Category_225"
# value: "malinois"
# , key: "Category_226"
# value: "briard"
# , key: "Category_227"
# value: "kelpie"
# , key: "Category_228"
# value: "komondor"
# , key: "Category_229"
# value: "Old English sheepdog, bobtail"
# , key: "Category_230"
# value: "Shetland sheepdog, Shetland sheep dog, Shetland"
# , key: "Category_231"
# value: "collie"
# , key: "Category_232"
# value: "Border collie"
# , key: "Category_233"
# value: "Bouvier des Flandres, Bouviers des Flandres"
# , key: "Category_234"
# value: "Rottweiler"
# , key: "Category_235"
# value: "German shepherd, German shepherd dog, German police dog, alsatian"
# , key: "Category_236"
# value: "Doberman, Doberman pinscher"
# , key: "Category_237"
# value: "miniature pinscher"
# , key: "Category_238"
# value: "Greater Swiss Mountain dog"
# , key: "Category_239"
# value: "Bernese mountain dog"
# , key: "Category_240"
# value: "Appenzeller"
# , key: "Category_241"
# value: "EntleBucher"
# , key: "Category_242"
# value: "boxer"
# , key: "Category_243"
# value: "bull mastiff"
# , key: "Category_244"
# value: "Tibetan mastiff"
# , key: "Category_245"
# value: "French bulldog"
# , key: "Category_246"
# value: "Great Dane"
# , key: "Category_247"
# value: "Saint Bernard, St Bernard"
# , key: "Category_248"
# value: "Eskimo dog, husky"
# , key: "Category_249"
# value: "malamute, malemute, Alaskan malamute"
# , key: "Category_250"
# value: "Siberian husky"
# , key: "Category_251"
# value: "dalmatian, coach dog, carriage dog"
# , key: "Category_252"
# value: "affenpinscher, monkey pinscher, monkey dog"
# , key: "Category_253"
# value: "basenji"
# , key: "Category_254"
# value: "pug, pug-dog"
# , key: "Category_255"
# value: "Leonberg"
# , key: "Category_256"
# value: "Newfoundland, Newfoundland dog"
# , key: "Category_257"
# value: "Great Pyrenees"
# , key: "Category_258"
# value: "Samoyed, Samoyede"
# , key: "Category_259"
# value: "Pomeranian"
# , key: "Category_260"
# value: "chow, chow chow"
# , key: "Category_261"
# value: "keeshond"
# , key: "Category_262"
# value: "Brabancon griffon"
# , key: "Category_263"
# value: "Pembroke, Pembroke Welsh corgi"
# , key: "Category_264"
# value: "Cardigan, Cardigan Welsh corgi"
# , key: "Category_265"
# value: "toy poodle"
# , key: "Category_266"
# value: "miniature poodle"
# , key: "Category_267"
# value: "standard poodle"
# , key: "Category_268"
# value: "Mexican hairless"
# , key: "Category_269"
# value: "timber wolf, grey wolf, gray wolf, Canis lupus"
# , key: "Category_270"
# value: "white wolf, Arctic wolf, Canis lupus tundrarum"
# , key: "Category_271"
# value: "red wolf, maned wolf, Canis rufus, Canis niger"
# , key: "Category_272"
# value: "coyote, prairie wolf, brush wolf, Canis latrans"
# , key: "Category_273"
# value: "dingo, warrigal, warragal, Canis dingo"
# , key: "Category_274"
# value: "dhole, Cuon alpinus"
# , key: "Category_275"
# value: "African hunting dog, hyena dog, Cape hunting dog, Lycaon pictus"
# , key: "Category_276"
# value: "hyena, hyaena"
# , key: "Category_277"
# value: "red fox, Vulpes vulpes"
# , key: "Category_278"
# value: "kit fox, Vulpes macrotis"
# , key: "Category_279"
# value: "Arctic fox, white fox, Alopex lagopus"
# , key: "Category_280"
# value: "grey fox, gray fox, Urocyon cinereoargenteus"
# , key: "Category_281"
# value: "tabby, tabby cat"
# , key: "Category_282"
# value: "tiger cat"
# , key: "Category_283"
# value: "Persian cat"
# , key: "Category_284"
# value: "Siamese cat, Siamese"
# , key: "Category_285"
# value: "Egyptian cat"
# , key: "Category_286"
# value: "cougar, puma, catamount, mountain lion, painter, panther, Felis concolor"
# , key: "Category_287"
# value: "lynx, catamount"
# , key: "Category_288"
# value: "leopard, Panthera pardus"
# , key: "Category_289"
# value: "snow leopard, ounce, Panthera uncia"
# , key: "Category_290"
# value: "jaguar, panther, Panthera onca, Felis onca"
# , key: "Category_291"
# value: "lion, king of beasts, Panthera leo"
# , key: "Category_292"
# value: "tiger, Panthera tigris"
# , key: "Category_293"
# value: "cheetah, chetah, Acinonyx jubatus"
# , key: "Category_294"
# value: "brown bear, bruin, Ursus arctos"
# , key: "Category_295"
# value: "American black bear, black bear, Ursus americanus, Euarctos americanus"
# , key: "Category_296"
# value: "ice bear, polar bear, Ursus Maritimus, Thalarctos maritimus"
# , key: "Category_297"
# value: "sloth bear, Melursus ursinus, Ursus ursinus"
# , key: "Category_298"
# value: "mongoose"
# , key: "Category_299"
# value: "meerkat, mierkat"
# , key: "Category_300"
# value: "tiger beetle"
# , key: "Category_301"
# value: "ladybug, ladybeetle, lady beetle, ladybird, ladybird beetle"
# , key: "Category_302"
# value: "ground beetle, carabid beetle"
# , key: "Category_303"
# value: "long-horned beetle, longicorn, longicorn beetle"
# , key: "Category_304"
# value: "leaf beetle, chrysomelid"
# , key: "Category_305"
# value: "dung beetle"
# , key: "Category_306"
# value: "rhinoceros beetle"
# , key: "Category_307"
# value: "weevil"
# , key: "Category_308"
# value: "fly"
# , key: "Category_309"
# value: "bee"
# , key: "Category_310"
# value: "ant, emmet, pismire"
# , key: "Category_311"
# value: "grasshopper, hopper"
# , key: "Category_312"
# value: "cricket"
# , key: "Category_313"
# value: "walking stick, walkingstick, stick insect"
# , key: "Category_314"
# value: "cockroach, roach"
# , key: "Category_315"
# value: "mantis, mantid"
# , key: "Category_316"
# value: "cicada, cicala"
# , key: "Category_317"
# value: "leafhopper"
# , key: "Category_318"
# value: "lacewing, lacewing fly"
# , key: "Category_319"
# value: "dragonfly, darning needle, devil\'s darning needle, sewing needle, snake feeder, snake doctor, mosquito hawk, skeeter hawk"
# , key: "Category_320"
# value: "damselfly"
# , key: "Category_321"
# value: "admiral"
# , key: "Category_322"
# value: "ringlet, ringlet butterfly"
# , key: "Category_323"
# value: "monarch, monarch butterfly, milkweed butterfly, Danaus plexippus"
# , key: "Category_324"
# value: "cabbage butterfly"
# , key: "Category_325"
# value: "sulphur butterfly, sulfur butterfly"
# , key: "Category_326"
# value: "lycaenid, lycaenid butterfly"
# , key: "Category_327"
# value: "starfish, sea star"
# , key: "Category_328"
# value: "sea urchin"
# , key: "Category_329"
# value: "sea cucumber, holothurian"
# , key: "Category_330"
# value: "wood rabbit, cottontail, cottontail rabbit"
# , key: "Category_331"
# value: "hare"
# , key: "Category_332"
# value: "Angora, Angora rabbit"
# , key: "Category_333"
# value: "hamster"
# , key: "Category_334"
# value: "porcupine, hedgehog"
# , key: "Category_335"
# value: "fox squirrel, eastern fox squirrel, Sciurus niger"
# , key: "Category_336"
# value: "marmot"
# , key: "Category_337"
# value: "beaver"
# , key: "Category_338"
# value: "guinea pig, Cavia cobaya"
# , key: "Category_339"
# value: "sorrel"
# , key: "Category_340"
# value: "zebra"
# , key: "Category_341"
# value: "hog, pig, grunter, squealer, Sus scrofa"
# , key: "Category_342"
# value: "wild boar, boar, Sus scrofa"
# , key: "Category_343"
# value: "warthog"
# , key: "Category_344"
# value: "hippopotamus, hippo, river horse, Hippopotamus amphibius"
# , key: "Category_345"
# value: "ox"
# , key: "Category_346"
# value: "water buffalo, water ox, Asiatic buffalo, Bubalus bubalis"
# , key: "Category_347"
# value: "bison"
# , key: "Category_348"
# value: "ram, tup"
# , key: "Category_349"
# value: "bighorn, bighorn sheep, cimarron, Rocky Mountain bighorn, Rocky Mountain sheep, Ovis canadensis"
# , key: "Category_350"
# value: "ibex, Capra ibex"
# , key: "Category_351"
# value: "hartebeest"
# , key: "Category_352"
# value: "impala, Aepyceros melampus"
# , key: "Category_353"
# value: "gazelle"
# , key: "Category_354"
# value: "Arabian camel, dromedary, Camelus dromedarius"
# , key: "Category_355"
# value: "llama"
# , key: "Category_356"
# value: "weasel"
# , key: "Category_357"
# value: "mink"
# , key: "Category_358"
# value: "polecat, fitch, foulmart, foumart, Mustela putorius"
# , key: "Category_359"
# value: "black-footed ferret, ferret, Mustela nigripes"
# , key: "Category_360"
# value: "otter"
# , key: "Category_361"
# value: "skunk, polecat, wood pussy"
# , key: "Category_362"
# value: "badger"
# , key: "Category_363"
# value: "armadillo"
# , key: "Category_364"
# value: "three-toed sloth, ai, Bradypus tridactylus"
# , key: "Category_365"
# value: "orangutan, orang, orangutang, Pongo pygmaeus"
# , key: "Category_366"
# value: "gorilla, Gorilla gorilla"
# , key: "Category_367"
# value: "chimpanzee, chimp, Pan troglodytes"
# , key: "Category_368"
# value: "gibbon, Hylobates lar"
# , key: "Category_369"
# value: "siamang, Hylobates syndactylus, Symphalangus syndactylus"
# , key: "Category_370"
# value: "guenon, guenon monkey"
# , key: "Category_371"
# value: "patas, hussar monkey, Erythrocebus patas"
# , key: "Category_372"
# value: "baboon"
# , key: "Category_373"
# value: "macaque"
# , key: "Category_374"
# value: "langur"
# , key: "Category_375"
# value: "colobus, colobus monkey"
# , key: "Category_376"
# value: "proboscis monkey, Nasalis larvatus"
# , key: "Category_377"
# value: "marmoset"
# , key: "Category_378"
# value: "capuchin, ringtail, Cebus capucinus"
# , key: "Category_379"
# value: "howler monkey, howler"
# , key: "Category_380"
# value: "titi, titi monkey"
# , key: "Category_381"
# value: "spider monkey, Ateles geoffroyi"
# , key: "Category_382"
# value: "squirrel monkey, Saimiri sciureus"
# , key: "Category_383"
# value: "Madagascar cat, ring-tailed lemur, Lemur catta"
# , key: "Category_384"
# value: "indri, indris, Indri indri, Indri brevicaudatus"
# , key: "Category_385"
# value: "Indian elephant, Elephas maximus"
# , key: "Category_386"
# value: "African elephant, Loxodonta africana"
# , key: "Category_387"
# value: "lesser panda, red panda, panda, bear cat, cat bear, Ailurus fulgens"
# , key: "Category_388"
# value: "giant panda, panda, panda bear, coon bear, Ailuropoda melanoleuca"
# , key: "Category_389"
# value: "barracouta, snoek"
# , key: "Category_390"
# value: "eel"
# , key: "Category_391"
# value: "coho, cohoe, coho salmon, blue jack, silver salmon, Oncorhynchus kisutch"
# , key: "Category_392"
# value: "rock beauty, Holocanthus tricolor"
# , key: "Category_393"
# value: "anemone fish"
# , key: "Category_394"
# value: "sturgeon"
# , key: "Category_395"
# value: "gar, garfish, garpike, billfish, Lepisosteus osseus"
# , key: "Category_396"
# value: "lionfish"
# , key: "Category_397"
# value: "puffer, pufferfish, blowfish, globefish"
# , key: "Category_398"
# value: "abacus"
# , key: "Category_399"
# value: "abaya"
# , key: "Category_400"
# value: "academic gown, academic robe, judge\'s robe"
# , key: "Category_401"
# value: "accordion, piano accordion, squeeze box"
# , key: "Category_402"
# value: "acoustic guitar"
# , key: "Category_403"
# value: "aircraft carrier, carrier, flattop, attack aircraft carrier"
# , key: "Category_404"
# value: "airliner"
# , key: "Category_405"
# value: "airship, dirigible"
# , key: "Category_406"
# value: "altar"
# , key: "Category_407"
# value: "ambulance"
# , key: "Category_408"
# value: "amphibian, amphibious vehicle"
# , key: "Category_409"
# value: "analog clock"
# , key: "Category_410"
# value: "apiary, bee house"
# , key: "Category_411"
# value: "apron"
# , key: "Category_412"
# value: "ashcan, trash can, garbage can, wastebin, ash bin, ash-bin, ashbin, dustbin, trash barrel, trash bin"
# , key: "Category_413"
# value: "assault rifle, assault gun"
# , key: "Category_414"
# value: "backpack, back pack, knapsack, packsack, rucksack, haversack"
# , key: "Category_415"
# value: "bakery, bakeshop, bakehouse"
# , key: "Category_416"
# value: "balance beam, beam"
# , key: "Category_417"
# value: "balloon"
# , key: "Category_418"
# value: "ballpoint, ballpoint pen, ballpen, Biro"
# , key: "Category_419"
# value: "Band Aid"
# , key: "Category_420"
# value: "banjo"
# , key: "Category_421"
# value: "bannister, banister, balustrade, balusters, handrail"
# , key: "Category_422"
# value: "barbell"
# , key: "Category_423"
# value: "barber chair"
# , key: "Category_424"
# value: "barbershop"
# , key: "Category_425"
# value: "barn"
# , key: "Category_426"
# value: "barometer"
# , key: "Category_427"
# value: "barrel, cask"
# , key: "Category_428"
# value: "barrow, garden cart, lawn cart, wheelbarrow"
# , key: "Category_429"
# value: "baseball"
# , key: "Category_430"
# value: "basketball"
# , key: "Category_431"
# value: "bassinet"
# , key: "Category_432"
# value: "bassoon"
# , key: "Category_433"
# value: "bathing cap, swimming cap"
# , key: "Category_434"
# value: "bath towel"
# , key: "Category_435"
# value: "bathtub, bathing tub, bath, tub"
# , key: "Category_436"
# value: "beach wagon, station wagon, wagon, estate car, beach waggon, station waggon, waggon"
# , key: "Category_437"
# value: "beacon, lighthouse, beacon light, pharos"
# , key: "Category_438"
# value: "beaker"
# , key: "Category_439"
# value: "bearskin, busby, shako"
# , key: "Category_440"
# value: "beer bottle"
# , key: "Category_441"
# value: "beer glass"
# , key: "Category_442"
# value: "bell cote, bell cot"
# , key: "Category_443"
# value: "bib"
# , key: "Category_444"
# value: "bicycle-built-for-two, tandem bicycle, tandem"
# , key: "Category_445"
# value: "bikini, two-piece"
# , key: "Category_446"
# value: "binder, ring-binder"
# , key: "Category_447"
# value: "binoculars, field glasses, opera glasses"
# , key: "Category_448"
# value: "birdhouse"
# , key: "Category_449"
# value: "boathouse"
# , key: "Category_450"
# value: "bobsled, bobsleigh, bob"
# , key: "Category_451"
# value: "bolo tie, bolo, bola tie, bola"
# , key: "Category_452"
# value: "bonnet, poke bonnet"
# , key: "Category_453"
# value: "bookcase"
# , key: "Category_454"
# value: "bookshop, bookstore, bookstall"
# , key: "Category_455"
# value: "bottlecap"
# , key: "Category_456"
# value: "bow"
# , key: "Category_457"
# value: "bow tie, bow-tie, bowtie"
# , key: "Category_458"
# value: "brass, memorial tablet, plaque"
# , key: "Category_459"
# value: "brassiere, bra, bandeau"
# , key: "Category_460"
# value: "breakwater, groin, groyne, mole, bulwark, seawall, jetty"
# , key: "Category_461"
# value: "breastplate, aegis, egis"
# , key: "Category_462"
# value: "broom"
# , key: "Category_463"
# value: "bucket, pail"
# , key: "Category_464"
# value: "buckle"
# , key: "Category_465"
# value: "bulletproof vest"
# , key: "Category_466"
# value: "bullet train, bullet"
# , key: "Category_467"
# value: "butcher shop, meat market"
# , key: "Category_468"
# value: "cab, hack, taxi, taxicab"
# , key: "Category_469"
# value: "caldron, cauldron"
# , key: "Category_470"
# value: "candle, taper, wax light"
# , key: "Category_471"
# value: "cannon"
# , key: "Category_472"
# value: "canoe"
# , key: "Category_473"
# value: "can opener, tin opener"
# , key: "Category_474"
# value: "cardigan"
# , key: "Category_475"
# value: "car mirror"
# , key: "Category_476"
# value: "carousel, carrousel, merry-go-round, roundabout, whirligig"
# , key: "Category_477"
# value: "carpenter\'s kit, tool kit"
# , key: "Category_478"
# value: "carton"
# , key: "Category_479"
# value: "car wheel"
# , key: "Category_480"
# value: "cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM"
# , key: "Category_481"
# value: "cassette"
# , key: "Category_482"
# value: "cassette player"
# , key: "Category_483"
# value: "castle"
# , key: "Category_484"
# value: "catamaran"
# , key: "Category_485"
# value: "CD player"
# , key: "Category_486"
# value: "cello, violoncello"
# , key: "Category_487"
# value: "cellular telephone, cellular phone, cellphone, cell, mobile phone"
# , key: "Category_488"
# value: "chain"
# , key: "Category_489"
# value: "chainlink fence"
# , key: "Category_490"
# value: "chain mail, ring mail, mail, chain armor, chain armour, ring armor, ring armour"
# , key: "Category_491"
# value: "chain saw, chainsaw"
# , key: "Category_492"
# value: "chest"
# , key: "Category_493"
# value: "chiffonier, commode"
# , key: "Category_494"
# value: "chime, bell, gong"
# , key: "Category_495"
# value: "china cabinet, china closet"
# , key: "Category_496"
# value: "Christmas stocking"
# , key: "Category_497"
# value: "church, church building"
# , key: "Category_498"
# value: "cinema, movie theater, movie theatre, movie house, picture palace"
# , key: "Category_499"
# value: "cleaver, meat cleaver, chopper"
# , key: "Category_500"
# value: "cliff dwelling"
# , key: "Category_501"
# value: "cloak"
# , key: "Category_502"
# value: "clog, geta, patten, sabot"
# , key: "Category_503"
# value: "cocktail shaker"
# , key: "Category_504"
# value: "coffee mug"
# , key: "Category_505"
# value: "coffeepot"
# , key: "Category_506"
# value: "coil, spiral, volute, whorl, helix"
# , key: "Category_507"
# value: "combination lock"
# , key: "Category_508"
# value: "computer keyboard, keypad"
# , key: "Category_509"
# value: "confectionery, confectionary, candy store"
# , key: "Category_510"
# value: "container ship, containership, container vessel"
# , key: "Category_511"
# value: "convertible"
# , key: "Category_512"
# value: "corkscrew, bottle screw"
# , key: "Category_513"
# value: "cornet, horn, trumpet, trump"
# , key: "Category_514"
# value: "cowboy boot"
# , key: "Category_515"
# value: "cowboy hat, ten-gallon hat"
# , key: "Category_516"
# value: "cradle"
# , key: "Category_517"
# value: "crane"
# , key: "Category_518"
# value: "crash helmet"
# , key: "Category_519"
# value: "crate"
# , key: "Category_520"
# value: "crib, cot"
# , key: "Category_521"
# value: "Crock Pot"
# , key: "Category_522"
# value: "croquet ball"
# , key: "Category_523"
# value: "crutch"
# , key: "Category_524"
# value: "cuirass"
# , key: "Category_525"
# value: "dam, dike, dyke"
# , key: "Category_526"
# value: "desk"
# , key: "Category_527"
# value: "desktop computer"
# , key: "Category_528"
# value: "dial telephone, dial phone"
# , key: "Category_529"
# value: "diaper, nappy, napkin"
# , key: "Category_530"
# value: "digital clock"
# , key: "Category_531"
# value: "digital watch"
# , key: "Category_532"
# value: "dining table, board"
# , key: "Category_533"
# value: "dishrag, dishcloth"
# , key: "Category_534"
# value: "dishwasher, dish washer, dishwashing machine"
# , key: "Category_535"
# value: "disk brake, disc brake"
# , key: "Category_536"
# value: "dock, dockage, docking facility"
# , key: "Category_537"
# value: "dogsled, dog sled, dog sleigh"
# , key: "Category_538"
# value: "dome"
# , key: "Category_539"
# value: "doormat, welcome mat"
# , key: "Category_540"
# value: "drilling platform, offshore rig"
# , key: "Category_541"
# value: "drum, membranophone, tympan"
# , key: "Category_542"
# value: "drumstick"
# , key: "Category_543"
# value: "dumbbell"
# , key: "Category_544"
# value: "Dutch oven"
# , key: "Category_545"
# value: "electric fan, blower"
# , key: "Category_546"
# value: "electric guitar"
# , key: "Category_547"
# value: "electric locomotive"
# , key: "Category_548"
# value: "entertainment center"
# , key: "Category_549"
# value: "envelope"
# , key: "Category_550"
# value: "espresso maker"
# , key: "Category_551"
# value: "face powder"
# , key: "Category_552"
# value: "feather boa, boa"
# , key: "Category_553"
# value: "file, file cabinet, filing cabinet"
# , key: "Category_554"
# value: "fireboat"
# , key: "Category_555"
# value: "fire engine, fire truck"
# , key: "Category_556"
# value: "fire screen, fireguard"
# , key: "Category_557"
# value: "flagpole, flagstaff"
# , key: "Category_558"
# value: "flute, transverse flute"
# , key: "Category_559"
# value: "folding chair"
# , key: "Category_560"
# value: "football helmet"
# , key: "Category_561"
# value: "forklift"
# , key: "Category_562"
# value: "fountain"
# , key: "Category_563"
# value: "fountain pen"
# , key: "Category_564"
# value: "four-poster"
# , key: "Category_565"
# value: "freight car"
# , key: "Category_566"
# value: "French horn, horn"
# , key: "Category_567"
# value: "frying pan, frypan, skillet"
# , key: "Category_568"
# value: "fur coat"
# , key: "Category_569"
# value: "garbage truck, dustcart"
# , key: "Category_570"
# value: "gasmask, respirator, gas helmet"
# , key: "Category_571"
# value: "gas pump, gasoline pump, petrol pump, island dispenser"
# , key: "Category_572"
# value: "goblet"
# , key: "Category_573"
# value: "go-kart"
# , key: "Category_574"
# value: "golf ball"
# , key: "Category_575"
# value: "golfcart, golf cart"
# , key: "Category_576"
# value: "gondola"
# , key: "Category_577"
# value: "gong, tam-tam"
# , key: "Category_578"
# value: "gown"
# , key: "Category_579"
# value: "grand piano, grand"
# , key: "Category_580"
# value: "greenhouse, nursery, glasshouse"
# , key: "Category_581"
# value: "grille, radiator grille"
# , key: "Category_582"
# value: "grocery store, grocery, food market, market"
# , key: "Category_583"
# value: "guillotine"
# , key: "Category_584"
# value: "hair slide"
# , key: "Category_585"
# value: "hair spray"
# , key: "Category_586"
# value: "half track"
# , key: "Category_587"
# value: "hammer"
# , key: "Category_588"
# value: "hamper"
# , key: "Category_589"
# value: "hand blower, blow dryer, blow drier, hair dryer, hair drier"
# , key: "Category_590"
# value: "hand-held computer, hand-held microcomputer"
# , key: "Category_591"
# value: "handkerchief, hankie, hanky, hankey"
# , key: "Category_592"
# value: "hard disc, hard disk, fixed disk"
# , key: "Category_593"
# value: "harmonica, mouth organ, harp, mouth harp"
# , key: "Category_594"
# value: "harp"
# , key: "Category_595"
# value: "harvester, reaper"
# , key: "Category_596"
# value: "hatchet"
# , key: "Category_597"
# value: "holster"
# , key: "Category_598"
# value: "home theater, home theatre"
# , key: "Category_599"
# value: "honeycomb"
# , key: "Category_600"
# value: "hook, claw"
# , key: "Category_601"
# value: "hoopskirt, crinoline"
# , key: "Category_602"
# value: "horizontal bar, high bar"
# , key: "Category_603"
# value: "horse cart, horse-cart"
# , key: "Category_604"
# value: "hourglass"
# , key: "Category_605"
# value: "iPod"
# , key: "Category_606"
# value: "iron, smoothing iron"
# , key: "Category_607"
# value: "jack-o\'-lantern"
# , key: "Category_608"
# value: "jean, blue jean, denim"
# , key: "Category_609"
# value: "jeep, landrover"
# , key: "Category_610"
# value: "jersey, T-shirt, tee shirt"
# , key: "Category_611"
# value: "jigsaw puzzle"
# , key: "Category_612"
# value: "jinrikisha, ricksha, rickshaw"
# , key: "Category_613"
# value: "joystick"
# , key: "Category_614"
# value: "kimono"
# , key: "Category_615"
# value: "knee pad"
# , key: "Category_616"
# value: "knot"
# , key: "Category_617"
# value: "lab coat, laboratory coat"
# , key: "Category_618"
# value: "ladle"
# , key: "Category_619"
# value: "lampshade, lamp shade"
# , key: "Category_620"
# value: "laptop, laptop computer"
# , key: "Category_621"
# value: "lawn mower, mower"
# , key: "Category_622"
# value: "lens cap, lens cover"
# , key: "Category_623"
# value: "letter opener, paper knife, paperknife"
# , key: "Category_624"
# value: "library"
# , key: "Category_625"
# value: "lifeboat"
# , key: "Category_626"
# value: "lighter, light, igniter, ignitor"
# , key: "Category_627"
# value: "limousine, limo"
# , key: "Category_628"
# value: "liner, ocean liner"
# , key: "Category_629"
# value: "lipstick, lip rouge"
# , key: "Category_630"
# value: "Loafer"
# , key: "Category_631"
# value: "lotion"
# , key: "Category_632"
# value: "loudspeaker, speaker, speaker unit, loudspeaker system, speaker system"
# , key: "Category_633"
# value: "loupe, jeweler\'s loupe"
# , key: "Category_634"
# value: "lumbermill, sawmill"
# , key: "Category_635"
# value: "magnetic compass"
# , key: "Category_636"
# value: "mailbag, postbag"
# , key: "Category_637"
# value: "mailbox, letter box"
# , key: "Category_638"
# value: "maillot"
# , key: "Category_639"
# value: "maillot, tank suit"
# , key: "Category_640"
# value: "manhole cover"
# , key: "Category_641"
# value: "maraca"
# , key: "Category_642"
# value: "marimba, xylophone"
# , key: "Category_643"
# value: "mask"
# , key: "Category_644"
# value: "matchstick"
# , key: "Category_645"
# value: "maypole"
# , key: "Category_646"
# value: "maze, labyrinth"
# , key: "Category_647"
# value: "measuring cup"
# , key: "Category_648"
# value: "medicine chest, medicine cabinet"
# , key: "Category_649"
# value: "megalith, megalithic structure"
# , key: "Category_650"
# value: "microphone, mike"
# , key: "Category_651"
# value: "microwave, microwave oven"
# , key: "Category_652"
# value: "military uniform"
# , key: "Category_653"
# value: "milk can"
# , key: "Category_654"
# value: "minibus"
# , key: "Category_655"
# value: "miniskirt, mini"
# , key: "Category_656"
# value: "minivan"
# , key: "Category_657"
# value: "missile"
# , key: "Category_658"
# value: "mitten"
# , key: "Category_659"
# value: "mixing bowl"
# , key: "Category_660"
# value: "mobile home, manufactured home"
# , key: "Category_661"
# value: "Model T"
# , key: "Category_662"
# value: "modem"
# , key: "Category_663"
# value: "monastery"
# , key: "Category_664"
# value: "monitor"
# , key: "Category_665"
# value: "moped"
# , key: "Category_666"
# value: "mortar"
# , key: "Category_667"
# value: "mortarboard"
# , key: "Category_668"
# value: "mosque"
# , key: "Category_669"
# value: "mosquito net"
# , key: "Category_670"
# value: "motor scooter, scooter"
# , key: "Category_671"
# value: "mountain bike, all-terrain bike, off-roader"
# , key: "Category_672"
# value: "mountain tent"
# , key: "Category_673"
# value: "mouse, computer mouse"
# , key: "Category_674"
# value: "mousetrap"
# , key: "Category_675"
# value: "moving van"
# , key: "Category_676"
# value: "muzzle"
# , key: "Category_677"
# value: "nail"
# , key: "Category_678"
# value: "neck brace"
# , key: "Category_679"
# value: "necklace"
# , key: "Category_680"
# value: "nipple"
# , key: "Category_681"
# value: "notebook, notebook computer"
# , key: "Category_682"
# value: "obelisk"
# , key: "Category_683"
# value: "oboe, hautboy, hautbois"
# , key: "Category_684"
# value: "ocarina, sweet potato"
# , key: "Category_685"
# value: "odometer, hodometer, mileometer, milometer"
# , key: "Category_686"
# value: "oil filter"
# , key: "Category_687"
# value: "organ, pipe organ"
# , key: "Category_688"
# value: "oscilloscope, scope, cathode-ray oscilloscope, CRO"
# , key: "Category_689"
# value: "overskirt"
# , key: "Category_690"
# value: "oxcart"
# , key: "Category_691"
# value: "oxygen mask"
# , key: "Category_692"
# value: "packet"
# , key: "Category_693"
# value: "paddle, boat paddle"
# , key: "Category_694"
# value: "paddlewheel, paddle wheel"
# , key: "Category_695"
# value: "padlock"
# , key: "Category_696"
# value: "paintbrush"
# , key: "Category_697"
# value: "pajama, pyjama, pj\'s, jammies"
# , key: "Category_698"
# value: "palace"
# , key: "Category_699"
# value: "panpipe, pandean pipe, syrinx"
# , key: "Category_700"
# value: "paper towel"
# , key: "Category_701"
# value: "parachute, chute"
# , key: "Category_702"
# value: "parallel bars, bars"
# , key: "Category_703"
# value: "park bench"
# , key: "Category_704"
# value: "parking meter"
# , key: "Category_705"
# value: "passenger car, coach, carriage"
# , key: "Category_706"
# value: "patio, terrace"
# , key: "Category_707"
# value: "pay-phone, pay-station"
# , key: "Category_708"
# value: "pedestal, plinth, footstall"
# , key: "Category_709"
# value: "pencil box, pencil case"
# , key: "Category_710"
# value: "pencil sharpener"
# , key: "Category_711"
# value: "perfume, essence"
# , key: "Category_712"
# value: "Petri dish"
# , key: "Category_713"
# value: "photocopier"
# , key: "Category_714"
# value: "pick, plectrum, plectron"
# , key: "Category_715"
# value: "pickelhaube"
# , key: "Category_716"
# value: "picket fence, paling"
# , key: "Category_717"
# value: "pickup, pickup truck"
# , key: "Category_718"
# value: "pier"
# , key: "Category_719"
# value: "piggy bank, penny bank"
# , key: "Category_720"
# value: "pill bottle"
# , key: "Category_721"
# value: "pillow"
# , key: "Category_722"
# value: "ping-pong ball"
# , key: "Category_723"
# value: "pinwheel"
# , key: "Category_724"
# value: "pirate, pirate ship"
# , key: "Category_725"
# value: "pitcher, ewer"
# , key: "Category_726"
# value: "plane, carpenter\'s plane, woodworking plane"
# , key: "Category_727"
# value: "planetarium"
# , key: "Category_728"
# value: "plastic bag"
# , key: "Category_729"
# value: "plate rack"
# , key: "Category_730"
# value: "plow, plough"
# , key: "Category_731"
# value: "plunger, plumber\'s helper"
# , key: "Category_732"
# value: "Polaroid camera, Polaroid Land camera"
# , key: "Category_733"
# value: "pole"
# , key: "Category_734"
# value: "police van, police wagon, paddy wagon, patrol wagon, wagon, black Maria"
# , key: "Category_735"
# value: "poncho"
# , key: "Category_736"
# value: "pool table, billiard table, snooker table"
# , key: "Category_737"
# value: "pop bottle, soda bottle"
# , key: "Category_738"
# value: "pot, flowerpot"
# , key: "Category_739"
# value: "potter\'s wheel"
# , key: "Category_740"
# value: "power drill"
# , key: "Category_741"
# value: "prayer rug, prayer mat"
# , key: "Category_742"
# value: "printer"
# , key: "Category_743"
# value: "prison, prison house"
# , key: "Category_744"
# value: "projectile, missile"
# , key: "Category_745"
# value: "projector"
# , key: "Category_746"
# value: "puck, hockey puck"
# , key: "Category_747"
# value: "punching bag, punch bag, punching ball, punchball"
# , key: "Category_748"
# value: "purse"
# , key: "Category_749"
# value: "quill, quill pen"
# , key: "Category_750"
# value: "quilt, comforter, comfort, puff"
# , key: "Category_751"
# value: "racer, race car, racing car"
# , key: "Category_752"
# value: "racket, racquet"
# , key: "Category_753"
# value: "radiator"
# , key: "Category_754"
# value: "radio, wireless"
# , key: "Category_755"
# value: "radio telescope, radio reflector"
# , key: "Category_756"
# value: "rain barrel"
# , key: "Category_757"
# value: "recreational vehicle, RV, R.V."
# , key: "Category_758"
# value: "reel"
# , key: "Category_759"
# value: "reflex camera"
# , key: "Category_760"
# value: "refrigerator, icebox"
# , key: "Category_761"
# value: "remote control, remote"
# , key: "Category_762"
# value: "restaurant, eating house, eating place, eatery"
# , key: "Category_763"
# value: "revolver, six-gun, six-shooter"
# , key: "Category_764"
# value: "rifle"
# , key: "Category_765"
# value: "rocking chair, rocker"
# , key: "Category_766"
# value: "rotisserie"
# , key: "Category_767"
# value: "rubber eraser, rubber, pencil eraser"
# , key: "Category_768"
# value: "rugby ball"
# , key: "Category_769"
# value: "rule, ruler"
# , key: "Category_770"
# value: "running shoe"
# , key: "Category_771"
# value: "safe"
# , key: "Category_772"
# value: "safety pin"
# , key: "Category_773"
# value: "saltshaker, salt shaker"
# , key: "Category_774"
# value: "sandal"
# , key: "Category_775"
# value: "sarong"
# , key: "Category_776"
# value: "sax, saxophone"
# , key: "Category_777"
# value: "scabbard"
# , key: "Category_778"
# value: "scale, weighing machine"
# , key: "Category_779"
# value: "school bus"
# , key: "Category_780"
# value: "schooner"
# , key: "Category_781"
# value: "scoreboard"
# , key: "Category_782"
# value: "screen, CRT screen"
# , key: "Category_783"
# value: "screw"
# , key: "Category_784"
# value: "screwdriver"
# , key: "Category_785"
# value: "seat belt, seatbelt"
# , key: "Category_786"
# value: "sewing machine"
# , key: "Category_787"
# value: "shield, buckler"
# , key: "Category_788"
# value: "shoe shop, shoe-shop, shoe store"
# , key: "Category_789"
# value: "shoji"
# , key: "Category_790"
# value: "shopping basket"
# , key: "Category_791"
# value: "shopping cart"
# , key: "Category_792"
# value: "shovel"
# , key: "Category_793"
# value: "shower cap"
# , key: "Category_794"
# value: "shower curtain"
# , key: "Category_795"
# value: "ski"
# , key: "Category_796"
# value: "ski mask"
# , key: "Category_797"
# value: "sleeping bag"
# , key: "Category_798"
# value: "slide rule, slipstick"
# , key: "Category_799"
# value: "sliding door"
# , key: "Category_800"
# value: "slot, one-armed bandit"
# , key: "Category_801"
# value: "snorkel"
# , key: "Category_802"
# value: "snowmobile"
# , key: "Category_803"
# value: "snowplow, snowplough"
# , key: "Category_804"
# value: "soap dispenser"
# , key: "Category_805"
# value: "soccer ball"
# , key: "Category_806"
# value: "sock"
# , key: "Category_807"
# value: "solar dish, solar collector, solar furnace"
# , key: "Category_808"
# value: "sombrero"
# , key: "Category_809"
# value: "soup bowl"
# , key: "Category_810"
# value: "space bar"
# , key: "Category_811"
# value: "space heater"
# , key: "Category_812"
# value: "space shuttle"
# , key: "Category_813"
# value: "spatula"
# , key: "Category_814"
# value: "speedboat"
# , key: "Category_815"
# value: "spider web, spider\'s web"
# , key: "Category_816"
# value: "spindle"
# , key: "Category_817"
# value: "sports car, sport car"
# , key: "Category_818"
# value: "spotlight, spot"
# , key: "Category_819"
# value: "stage"
# , key: "Category_820"
# value: "steam locomotive"
# , key: "Category_821"
# value: "steel arch bridge"
# , key: "Category_822"
# value: "steel drum"
# , key: "Category_823"
# value: "stethoscope"
# , key: "Category_824"
# value: "stole"
# , key: "Category_825"
# value: "stone wall"
# , key: "Category_826"
# value: "stopwatch, stop watch"
# , key: "Category_827"
# value: "stove"
# , key: "Category_828"
# value: "strainer"
# , key: "Category_829"
# value: "streetcar, tram, tramcar, trolley, trolley car"
# , key: "Category_830"
# value: "stretcher"
# , key: "Category_831"
# value: "studio couch, day bed"
# , key: "Category_832"
# value: "stupa, tope"
# , key: "Category_833"
# value: "submarine, pigboat, sub, U-boat"
# , key: "Category_834"
# value: "suit, suit of clothes"
# , key: "Category_835"
# value: "sundial"
# , key: "Category_836"
# value: "sunglass"
# , key: "Category_837"
# value: "sunglasses, dark glasses, shades"
# , key: "Category_838"
# value: "sunscreen, sunblock, sun blocker"
# , key: "Category_839"
# value: "suspension bridge"
# , key: "Category_840"
# value: "swab, swob, mop"
# , key: "Category_841"
# value: "sweatshirt"
# , key: "Category_842"
# value: "swimming trunks, bathing trunks"
# , key: "Category_843"
# value: "swing"
# , key: "Category_844"
# value: "switch, electric switch, electrical switch"
# , key: "Category_845"
# value: "syringe"
# , key: "Category_846"
# value: "table lamp"
# , key: "Category_847"
# value: "tank, army tank, armored combat vehicle, armoured combat vehicle"
# , key: "Category_848"
# value: "tape player"
# , key: "Category_849"
# value: "teapot"
# , key: "Category_850"
# value: "teddy, teddy bear"
# , key: "Category_851"
# value: "television, television system"
# , key: "Category_852"
# value: "tennis ball"
# , key: "Category_853"
# value: "thatch, thatched roof"
# , key: "Category_854"
# value: "theater curtain, theatre curtain"
# , key: "Category_855"
# value: "thimble"
# , key: "Category_856"
# value: "thresher, thrasher, threshing machine"
# , key: "Category_857"
# value: "throne"
# , key: "Category_858"
# value: "tile roof"
# , key: "Category_859"
# value: "toaster"
# , key: "Category_860"
# value: "tobacco shop, tobacconist shop, tobacconist"
# , key: "Category_861"
# value: "toilet seat"
# , key: "Category_862"
# value: "torch"
# , key: "Category_863"
# value: "totem pole"
# , key: "Category_864"
# value: "tow truck, tow car, wrecker"
# , key: "Category_865"
# value: "toyshop"
# , key: "Category_866"
# value: "tractor"
# , key: "Category_867"
# value: "trailer truck, tractor trailer, trucking rig, rig, articulated lorry, semi"
# , key: "Category_868"
# value: "tray"
# , key: "Category_869"
# value: "trench coat"
# , key: "Category_870"
# value: "tricycle, trike, velocipede"
# , key: "Category_871"
# value: "trimaran"
# , key: "Category_872"
# value: "tripod"
# , key: "Category_873"
# value: "triumphal arch"
# , key: "Category_874"
# value: "trolleybus, trolley coach, trackless trolley"
# , key: "Category_875"
# value: "trombone"
# , key: "Category_876"
# value: "tub, vat"
# , key: "Category_877"
# value: "turnstile"
# , key: "Category_878"
# value: "typewriter keyboard"
# , key: "Category_879"
# value: "umbrella"
# , key: "Category_880"
# value: "unicycle, monocycle"
# , key: "Category_881"
# value: "upright, upright piano"
# , key: "Category_882"
# value: "vacuum, vacuum cleaner"
# , key: "Category_883"
# value: "vase"
# , key: "Category_884"
# value: "vault"
# , key: "Category_885"
# value: "velvet"
# , key: "Category_886"
# value: "vending machine"
# , key: "Category_887"
# value: "vestment"
# , key: "Category_888"
# value: "viaduct"
# , key: "Category_889"
# value: "violin, fiddle"
# , key: "Category_890"
# value: "volleyball"
# , key: "Category_891"
# value: "waffle iron"
# , key: "Category_892"
# value: "wall clock"
# , key: "Category_893"
# value: "wallet, billfold, notecase, pocketbook"
# , key: "Category_894"
# value: "wardrobe, closet, press"
# , key: "Category_895"
# value: "warplane, military plane"
# , key: "Category_896"
# value: "washbasin, handbasin, washbowl, lavabo, wash-hand basin"
# , key: "Category_897"
# value: "washer, automatic washer, washing machine"
# , key: "Category_898"
# value: "water bottle"
# , key: "Category_899"
# value: "water jug"
# , key: "Category_900"
# value: "water tower"
# , key: "Category_901"
# value: "whiskey jug"
# , key: "Category_902"
# value: "whistle"
# , key: "Category_903"
# value: "wig"
# , key: "Category_904"
# value: "window screen"
# , key: "Category_905"
# value: "window shade"
# , key: "Category_906"
# value: "Windsor tie"
# , key: "Category_907"
# value: "wine bottle"
# , key: "Category_908"
# value: "wing"
# , key: "Category_909"
# value: "wok"
# , key: "Category_910"
# value: "wooden spoon"
# , key: "Category_911"
# value: "wool, woolen, woollen"
# , key: "Category_912"
# value: "worm fence, snake fence, snake-rail fence, Virginia fence"
# , key: "Category_913"
# value: "wreck"
# , key: "Category_914"
# value: "yawl"
# , key: "Category_915"
# value: "yurt"
# , key: "Category_916"
# value: "web site, website, internet site, site"
# , key: "Category_917"
# value: "comic book"
# , key: "Category_918"
# value: "crossword puzzle, crossword"
# , key: "Category_919"
# value: "street sign"
# , key: "Category_920"
# value: "traffic light, traffic signal, stoplight"
# , key: "Category_921"
# value: "book jacket, dust cover, dust jacket, dust wrapper"
# , key: "Category_922"
# value: "menu"
# , key: "Category_923"
# value: "plate"
# , key: "Category_924"
# value: "guacamole"
# , key: "Category_925"
# value: "consomme"
# , key: "Category_926"
# value: "hot pot, hotpot"
# , key: "Category_927"
# value: "trifle"
# , key: "Category_928"
# value: "ice cream, icecream"
# , key: "Category_929"
# value: "ice lolly, lolly, lollipop, popsicle"
# , key: "Category_930"
# value: "French loaf"
# , key: "Category_931"
# value: "bagel, beigel"
# , key: "Category_932"
# value: "pretzel"
# , key: "Category_933"
# value: "cheeseburger"
# , key: "Category_934"
# value: "hotdog, hot dog, red hot"
# , key: "Category_935"
# value: "mashed potato"
# , key: "Category_936"
# value: "head cabbage"
# , key: "Category_937"
# value: "broccoli"
# , key: "Category_938"
# value: "cauliflower"
# , key: "Category_939"
# value: "zucchini, courgette"
# , key: "Category_940"
# value: "spaghetti squash"
# , key: "Category_941"
# value: "acorn squash"
# , key: "Category_942"
# value: "butternut squash"
# , key: "Category_943"
# value: "cucumber, cuke"
# , key: "Category_944"
# value: "artichoke, globe artichoke"
# , key: "Category_945"
# value: "bell pepper"
# , key: "Category_946"
# value: "cardoon"
# , key: "Category_947"
# value: "mushroom"
# , key: "Category_948"
# value: "Granny Smith"
# , key: "Category_949"
# value: "strawberry"
# , key: "Category_950"
# value: "orange"
# , key: "Category_951"
# value: "lemon"
# , key: "Category_952"
# value: "fig"
# , key: "Category_953"
# value: "pineapple, ananas"
# , key: "Category_954"
# value: "banana"
# , key: "Category_955"
# value: "jackfruit, jak, jack"
# , key: "Category_956"
# value: "custard apple"
# , key: "Category_957"
# value: "pomegranate"
# , key: "Category_958"
# value: "hay"
# , key: "Category_959"
# value: "carbonara"
# , key: "Category_960"
# value: "chocolate sauce, chocolate syrup"
# , key: "Category_961"
# value: "dough"
# , key: "Category_962"
# value: "meat loaf, meatloaf"
# , key: "Category_963"
# value: "pizza, pizza pie"
# , key: "Category_964"
# value: "potpie"
# , key: "Category_965"
# value: "burrito"
# , key: "Category_966"
# value: "red wine"
# , key: "Category_967"
# value: "espresso"
# , key: "Category_968"
# value: "cup"
# , key: "Category_969"
# value: "eggnog"
# , key: "Category_970"
# value: "alp"
# , key: "Category_971"
# value: "bubble"
# , key: "Category_972"
# value: "cliff, drop, drop-off"
# , key: "Category_973"
# value: "coral reef"
# , key: "Category_974"
# value: "geyser"
# , key: "Category_975"
# value: "lakeside, lakeshore"
# , key: "Category_976"
# value: "promontory, headland, head, foreland"
# , key: "Category_977"
# value: "sandbar, sand bar"
# , key: "Category_978"
# value: "seashore, coast, seacoast, sea-coast"
# , key: "Category_979"
# value: "valley, vale"
# , key: "Category_980"
# value: "volcano"
# , key: "Category_981"
# value: "ballplayer, baseball player"
# , key: "Category_982"
# value: "groom, bridegroom"
# , key: "Category_983"
# value: "scuba diver"
# , key: "Category_984"
# value: "rapeseed"
# , key: "Category_985"
# value: "daisy"
# , key: "Category_986"
# value: "yellow lady\'s slipper, yellow lady-slipper, Cypripedium calceolus, Cypripedium parviflorum"
# , key: "Category_987"
# value: "corn"
# , key: "Category_988"
# value: "acorn"
# , key: "Category_989"
# value: "hip, rose hip, rosehip"
# , key: "Category_990"
# value: "buckeye, horse chestnut, conker"
# , key: "Category_991"
# value: "coral fungus"
# , key: "Category_992"
# value: "agaric"
# , key: "Category_993"
# value: "gyromitra"
# , key: "Category_994"
# value: "stinkhorn, carrion fungus"
# , key: "Category_995"
# value: "earthstar"
# , key: "Category_996"
# value: "hen-of-the-woods, hen of the woods, Polyporus frondosus, Grifola frondosa"
# , key: "Category_997"
# value: "bolete"
# , key: "Category_998"
# value: "ear, spike, capitulum"
# , key: "Category_999"
# value: "toilet tissue, toilet paper, bathroom tissue"
# ]

# %% [markdown]
# Other information

# %%
model_proto.producer_name = 'MXNet'
model_proto.producer_version = mx.__version__
model_proto.domain = 'com.ericsson.nomadiclab'
model_proto.model_version = 2
model_proto.doc_string = """ResNet152 v2 model for image classification.
Take an image as input and classifies the major object in the image into a set of 1000 predefined categories.
Model was trained in ImageNet dataset which contains images from 1000 categories.
Has 152 layers, excluding pre- and postprocessing.
"""
print(model_proto.producer_name)
print(model_proto.producer_version)
print(model_proto.domain)
print(model_proto.model_version)
print(model_proto.doc_string)
# Out:
# MXNet
# 1.3.1
# com.ericsson.nomadiclab
# 2
# ResNet152 v2 model for image classification.
# Take an image as input and classifies the major object in the image into a set of 1000 predefined categories.
# Model was trained in ImageNet dataset which contains images from 1000 categories.
# Has 152 layers, excluding pre- and postprocessing.

# %% [markdown]
# Now the model is ready to be consumed by intelligence layer. We save it to disk.

# %%
onnx.save_model(model_proto, 'resnet152v2_prepostprocess_denotated.onnx')

# %%
tmp = onnx.load('resnet152v2_prepostprocess_denotated.onnx')

# %%
all_passes = optimizer.get_available_passes()
print("Available optimization passes:")
for p in all_passes:
    print(p)
print()
# Out:
# Available optimization passes:
# eliminate_identity
# eliminate_nop_pad
# eliminate_nop_transpose
# eliminate_unused_initializer
# extract_constant_to_initializer
# fuse_add_bias_into_conv
# fuse_bn_into_conv
# fuse_consecutive_squeezes
# fuse_consecutive_transposes
# fuse_transpose_into_gemm
# lift_lexical_references
# nop
# split_init
# split_predict

# %%
passes = ['eliminate_nop_pad']
optimized_model = optimizer.optimize(tmp, passes)

# %%
onnx.save_model(optimized_model, 'tmp.onnx')

# %%
print(optimized_model.opset_import)
# Out:
# [domain: ""
# version: 8
# ]

# %%
print(optimized_model.graph.node[3].domain)

# %%
onnx.checker.check_model(tmp)
print('The model is checked!')
# Out:
# The model is checked!
